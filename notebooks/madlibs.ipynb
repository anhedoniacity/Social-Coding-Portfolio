# %%
# pick nonsense words
pluralnoun1 = 'catboys'
verb1 = 'extrapolate'  #infinitive
food = 'sandwich'
concept1 = 'frailty'
adj1 = 'glittering'
noun3 = 'tomato'
concept2 = 'comprehension'
typeofpet = 'cat'
typeofdocument = 'e-mail'
superamericanthings = 'Assault Rifles'

#madlib text (The Preamble of the US Constitution)
print(f"""We the {pluralnoun1} of the United States, in Order to {verb1} a more perfect {food},
establish {concept1}, insure {adj1} Tranquility, provide for the common {noun3},
      promote the general Welfare,  and secure the Blessings of {concept2} to ourselves and our {typeofpet},
do ordain and establish this {typeofdocument} for the United {superamericanthings} of America.""")
# Out:
# We the catboys of the United States, in Order to extrapolate a more perfect sandwich,
# establish frailty, insure glittering Tranquility, provide for the common tomato,
#       promote the general Welfare,  and secure the Blessings of comprehension to ourselves and our cat,
# do ordain and establish this e-mail for the United Assault Rifles of America.
