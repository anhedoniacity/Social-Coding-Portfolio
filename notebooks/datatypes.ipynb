# %%
# Define biographical variables
name = 'L'  # string
age = 22 # integer
home_town = 'Brooklyn'  # string
favorite_food = 'freeze-dried ice cream'  # string
dog_years_age = (age)/7.5  # float
student = True  # boolean

# %%
print(f'✨This is... {name}!✨')
print(f"""{name} likes {favorite_food} and once lived in {home_town}.
{name} is {age} years old, which is {dog_years_age} in dog years.
The statement '{name} is a student' is {student}.
""")
# Out:
# ✨This is... L!✨
# L likes freeze-dried ice cream and once lived in Brooklyn.
# L is 22 years old, which is 2.933333333333333 in dog years.
# The statement 'L is a student' is True.

# %%
print(f"""
name = {type(name)}
age = {type(age)}
home_town = {type(home_town)}
favorite_food = {type(favorite_food)}
dog_years_age = {type(dog_years_age)}
student = {type(student)}
""")
# Out:
# name = <class 'str'>
# age = <class 'int'>
# home_town = <class 'str'>
# favorite_food = <class 'str'>
# dog_years_age = <class 'float'>
# student = <class 'bool'>

# %%
# Adding favorite movie variable
favorite_movie = 'Spirited Away'  # string

# Update the print statement
print(f'✨This is... {name}!✨')
print(f"""{name} likes {favorite_food} and once lived in {home_town}.
{name} is {age} years old, which is {dog_years_age} in dog years.
The statement '{name} is a student' is {student}.
{name}'s favorite movie is {favorite_movie}.
""")
# Out:
# ✨This is... L!✨
# L likes freeze-dried ice cream and once lived in Brooklyn.
# L is 22 years old, which is 2.933333333333333 in dog years.
# The statement 'L is a student' is True.
# L's favorite movie is Spirited Away.
